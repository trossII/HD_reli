# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../Downloads/harddrive.csv')

# %%
data.describe()
# Out:
#        capacity_bytes       failure  smart_1_normalized   smart_1_raw  \
# count    3.179295e+06  3.179295e+06        3.179295e+06  3.179295e+06
# mean    1.849552e-311  6.762506e-05        1.121816e+02  6.856751e+07
# std      0.000000e+00  8.223169e-03        1.871325e+01  8.002785e+07
# min     3.953828e-313  0.000000e+00        3.300000e+01  0.000000e+00
# 25%     1.976651e-311  0.000000e+00        1.000000e+02  0.000000e+00
# 50%     1.976651e-311  0.000000e+00        1.120000e+02  2.984580e+07
# 75%     1.976651e-311  0.000000e+00        1.170000e+02  1.343214e+08
# max     3.953298e-311  1.000000e+00        2.000000e+02  1.916485e+09
#
#        smart_2_normalized   smart_2_raw  smart_3_normalized   smart_3_raw  \
# count        1.259118e+06  1.259118e+06        3.179295e+06  3.179295e+06
# mean         1.287652e+02  7.491735e+01        1.052967e+02  3.655617e+02
# std          2.488450e+01  4.557482e+01        1.870145e+01  1.089088e+03
# ...

# %%
data.head()
# Out:
#          date    serial_number                    model  capacity_bytes  \
# 0  2016-01-01   MJ0351YNG9Z0XA  Hitachi HDS5C3030ALA630   1.482490e-311
# 1  2016-01-01         Z305B2QN              ST4000DM000   1.976651e-311
# 2  2016-01-01   MJ0351YNG9Z7LA  Hitachi HDS5C3030ALA630   1.482490e-311
# 3  2016-01-01   MJ0351YNGABYAA  Hitachi HDS5C3030ALA630   1.482490e-311
# 4  2016-01-01  WD-WMC4N2899475             WDC WD30EFRX   1.482490e-311
#
#    failure  smart_1_normalized  smart_1_raw  smart_2_normalized  smart_2_raw  \
# 0        0                 100            0               135.0        108.0
# 1        0                 113     54551400                 NaN          NaN
# 2        0                 100            0               136.0        104.0
# 3        0                 100            0               136.0        104.0
# 4        0                 200            0                 NaN          NaN
#
#    smart_3_normalized  ...  smart_250_normalized  smart_250_raw  \
# ...

# %%
data.shape
# Out:
# (3179295, 95)

# %%
data.dropna(axis=1,how='all',inplace=True)

# %%
data.head()
# Out:
#          date    serial_number                    model  capacity_bytes  \
# 0  2016-01-01   MJ0351YNG9Z0XA  Hitachi HDS5C3030ALA630   1.482490e-311
# 1  2016-01-01         Z305B2QN              ST4000DM000   1.976651e-311
# 2  2016-01-01   MJ0351YNG9Z7LA  Hitachi HDS5C3030ALA630   1.482490e-311
# 3  2016-01-01   MJ0351YNGABYAA  Hitachi HDS5C3030ALA630   1.482490e-311
# 4  2016-01-01  WD-WMC4N2899475             WDC WD30EFRX   1.482490e-311
#
#    failure  smart_1_normalized  smart_1_raw  smart_2_normalized  smart_2_raw  \
# 0        0                 100            0               135.0        108.0
# 1        0                 113     54551400                 NaN          NaN
# 2        0                 100            0               136.0        104.0
# 3        0                 100            0               136.0        104.0
# 4        0                 200            0                 NaN          NaN
#
#    smart_3_normalized  ...  smart_242_normalized  smart_242_raw  \
# ...

# %%
data.shape
# Out:
# (3179295, 91)

# %%
hd_fail = data[data['failure']==1]

# %%
hd_fail.shape
# Out:
# (215, 91)

# %%
hd_fail['serial_number'].value_counts().shape
# Out:
# (205,)

# %%
hd_good = data[data['failure']==0]
hd_good.shape
# Out:
# (3179080, 91)

# %%
data['model'].value_counts().shape
# Out:
# (69,)

# %%
data['serial_number'].value_counts().shape
# Out:
# (65993,)

# %%
data.groupby('model')['failure'].sum().sort_values(ascending=False)
# Out:
# model
# ST4000DM000                139
# ST320LT007                  15
# Hitachi HDS722020ALA330     13
# WDC WD800AAJS                6
# WDC WD30EFRX                 6
#                           ...
# WDC WD10EADX                 0
# WDC WD10EACS                 0
# WDC WD800JD                  0
# TOSHIBA MD04ABA400V          0
# HGST HDS5C4040ALE630         0
# Name: failure, Length: 69, dtype: int64

# %%
st4=data[data['model']=='ST4000DM000']

# %%
st4.shape
# Out:
# (1681473, 91)

# %%
st4.head()
# Out:
#           date serial_number        model  capacity_bytes  failure  \
# 1   2016-01-01      Z305B2QN  ST4000DM000   1.976651e-311        0
# 7   2016-01-01      S300Z6K9  ST4000DM000   1.976651e-311        0
# 8   2016-01-01      S300Z6K8  ST4000DM000   1.976651e-311        0
# 9   2016-01-01      Z302PGH8  ST4000DM000   1.976651e-311        0
# 10  2016-01-01      Z3023VGH  ST4000DM000   1.976651e-311        0
#
#     smart_1_normalized  smart_1_raw  smart_2_normalized  smart_2_raw  \
# 1                  113     54551400                 NaN          NaN
# 7                  107     13985080                 NaN          NaN
# 8                  116    109242152                 NaN          NaN
# 9                  112     46112000                 NaN          NaN
# 10                 116    117245752                 NaN          NaN
#
#     smart_3_normalized  ...  smart_242_normalized  smart_242_raw  \
# 1                   96  ...                 100.0  1.316882e-315
# ...

# %%
st4_fail=st4[st4['failure']==1]

# %%
st4_fail.shape
# Out:
# (139, 91)

# %%
st4_fail['serial_number'].value_counts().shape
# Out:
# (131,)
